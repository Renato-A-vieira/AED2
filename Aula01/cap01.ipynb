# %%
frutas = ["maçã", "banana", "laranja"]
frutas.append("morango")
print(frutas)
# Out:
# ['maçã', 'banana', 'laranja', 'morango']

# %%
livros = ["O Senhor dos Aneis", "Bananinha", "Codigo da Vinci"]

removido = livros.pop()

print(f"Livro removido: {removido}")
print(f"Pilha restante: {livros}")
# Out:
# Livro removido: Codigo da Vinci
# Pilha restante: ['O Senhor dos Aneis', 'Bananinha']

# %%
clientes = ["Renato", "Amanda", "Carla"]
clientes.append("Piva")
saiu = clientes.pop(0)

print(f"Cliente que saiu: {saiu}")
print(f"Fila restante: {clientes}")
# Out:
# Cliente que saiu: Renato
# Fila restante: ['Amanda', 'Carla', 'Piva']

# %%
contatos = {"Renato": "1234-4321", "Amanda": "2345-5432"}

contatos["João"] = "2222-3344"

print(f"Telefone da Amanda: {contatos['Amanda']}")
# Out:
# Telefone da Ana: 1234-5678

# %%
agenda = {}

def adicionar_contato(nome, telefone, email):
    agenda[nome] = {"telefone": telefone, "email": email}
    print(f"Contato {nome} adicionado com sucesso!")

def buscar_contato(nome):
    if nome in agenda:
        info = agenda[nome]
        print(f"Nome: {nome} | Tel: {info['telefone']} | Email: {info['email']}")
    else:
        print("Contato não encontrado.")

def listar_contatos():
    print("Contatos")
    for nome, info in agenda.items():
        print(f"Nome: {nome} - Tel: {info['telefone']}")

adicionar_contato("Renato", "1234-4321", "Renato@renato.com")
adicionar_contato("Amanda", "9876-6789", "bruno@email.com")
buscar_contato("Renato")
listar_contatos()
# Out:
# Contato Renato adicionado com sucesso!
# Contato Amanda adicionado com sucesso!
# Nome: Renato | Tel: 1234-4321 | Email: Renato@renato.com
# Contatos
# Nome: Renato - Tel: 1234-4321
# Nome: Amanda - Tel: 9876-6789

# %%
tarefas_pendentes = []

def adicionar_tarefa(tarefa):
    tarefas_pendentes.append(tarefa)
    print(f"Tarefa '{tarefa}' adicionada!")

def marcar_concluida(tarefa):
    if tarefa in tarefas_pendentes:
        tarefas_pendentes.remove(tarefa)
        print(f"Tarefa '{tarefa}' marcada como feita.")
    else:
        print("Tarefa não encontrada.")

def visualizar_tarefas():
    print("Pendentes")
    if not tarefas_pendentes:
        print("Nenhuma tarefa pendente.")
    for i, tarefa in enumerate(tarefas_pendentes, 1):
        print(f"{i}. {tarefa}")

adicionar_tarefa("Estudar Power bi")
adicionar_tarefa("Algoritmos")
visualizar_tarefas()
marcar_concluida("Matématica")
visualizar_tarefas()
# Out:
# Tarefa 'Estudar Git e GitHub' adicionada!
# Tarefa 'Revisar lógica proposicional' adicionada!
#
# --- Tarefas Pendentes ---
# 1. Estudar Git e GitHub
# 2. Revisar lógica proposicional
# Tarefa 'Estudar Git e GitHub' marcada como concluída e removida.
#
# --- Tarefas Pendentes ---
# 1. Revisar lógica proposicional
