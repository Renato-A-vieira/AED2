# %%
class Stack:
    def __init__(self):
        self.itens = []
    def is_empty(self):
        return self.itens == []
    def push(self, itens):
        self.itens.append(itens)
        print(f"PUSH {self.itens}")
    def pop(self):
        if s.is_empty():
            print("A lista está vazia")
        else:
            print(f"Pop {self.itens[-1]}")
            return self.itens.pop()
    def peek(self):
        return self.itens[-1]
    def print_stack(self):
        print(self.itens)
    def size(self):
        return len(self.itens)

# %%
s = Stack()
print(s.is_empty())
s.push(3)
s.push(4)
s.pop()
s.push(9)
s.push(8)
s.push(5)
s.print_stack()
s.size()
s.pop()
s.print_stack()
print(s.is_empty())
s.peek()
# Out:
# True
# PUSH [3]
# PUSH [3, 4]
# Pop 4
# PUSH [3, 9]
# PUSH [3, 9, 8]
# PUSH [3, 9, 8, 5]
# [3, 9, 8, 5]
# Pop 5
# [3, 9, 8]
# False
# 8

# %%
class Stack:
    def __init__(self):
        self.item = []
    def is_empty(self):
        return self.item == []
    def push(self, numero):
        self.item.append(numero)
    def pop(self):
        if s.is_empty():
            print("O codigo binario está vazio")
        else:
            return self.item.pop()
    def peek(self):
        return self.itens[-1]
    def print_stack(self):
        print(self.itens)
    def size(self):
        return len(self.itens)
    def decimal_binario(self, numero):
        s = Stack()
        while numero > 0:
            resto = numero % 2
            s.push (resto)
            numero = numero // 2
        binario = ''
        while not self.is_empty:
            binario = binario + str(s.pop())
        return binario

    while True:
        entrada = input()
    
        if entrada == "sair":
            break
        numero = int(entrada)
        print(decimal_binario(numero))

# %%
s.decimal_binario()
